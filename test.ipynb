# %%
import pandas as pd 
import requests
import json

# %%
r = requests.get("https://sdacelo-real-time-fraud-detection.hf.space/current-transactions")
r.json()

# %%
# Double parsing car l'API encode 2 fois
donnees = json.loads(r.text)
donnees = json.loads(donnees)

donnees_transaction = donnees['data']
columns = donnees['columns']   

df = pd.DataFrame(donnees_transaction, columns=columns).drop(columns=['is_fraud'])
print(df)

# %%
df['unix_time'] = df['current_time']/1000
df['trans_date_trans_time'] = pd.to_datetime(df['current_time'], unit='ms').dt.strftime('%Y-%m-%d %H:%M:%S')
df.drop(columns=['current_time'], inplace=True)
df = df.astype({col: "float64" for col in df.select_dtypes(include=["int"]).columns})
print(df)

# %%
type(df['cc_num'][0])

# %%
df = df.astype({col: "float64" for col in df.select_dtypes(include=["int"]).columns})

# %%
pd.DataFrame(df)

# %%
import mlflow
logged_model = 'runs:/bf781e6a105445afa07d064f8f1f30a3/fraud_detector'

# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(logged_model)

# Predict on a Pandas DataFrame.
prediction = loaded_model.predict(pd.DataFrame(df))

# %%
print("Données de la transaction : \n", df)
print("\nPrediction du modèle (0 = légitime, 1 = frauduleuse) : \n", prediction)

# %%
from sqlalchemy import create_engine

# Connection string pour Neon
connection_string = "postgresql://neondb_owner:npg_wrzm54cJPQoI@ep-muddy-boat-abfjlk8a-pooler.eu-west-2.aws.neon.tech/neondb?sslmode=require&channel_binding=require"

engine = create_engine(connection_string)

# %%
prediction

# %%
df['prediction'] = prediction

# %%
df['prediction']

# %%
# Écrire tout le DataFrame
df.to_sql('transactions', engine, if_exists='replace', index=False)

# %%
from dotenv import load_dotenv
load_dotenv()

import pandas as pd
import requests
import json
import mlflow
from sqlalchemy import create_engine
import os
 
# Set tracking URI 
mlflow.set_tracking_uri("http://localhost:4000/")

# Model informations
logged_model = 'runs:/bf781e6a105445afa07d064f8f1f30a3/fraud_detector'
loaded_model = mlflow.pyfunc.load_model(logged_model)

# Database connection string
connection_string = os.getenv("BACKEND_STORE_URI")
engine = create_engine(connection_string)

for i in range(250) :
    print("=====================================")
    print(f"--- Processing transaction {i+1} ---")
    print("calling API to generate transaction...")
    
    # Call external API to get a transaction
    r = requests.get("https://sdacelo-real-time-fraud-detection.hf.space/current-transactions")

    if r.status_code == 200:
        # Double parsing car l'API encode 2 fois
        donnees = json.loads(r.text)
        donnees = json.loads(donnees)

        donnees_transaction = donnees['data']
        columns = donnees['columns']  

        # Prepare data to stick input formtat of model 

        df = pd.DataFrame(donnees_transaction, columns=columns)
        df['unix_time'] = df['current_time']/1000
        df['trans_date_trans_time'] = pd.to_datetime(df['current_time'], unit='ms').dt.strftime('%Y-%m-%d %H:%M:%S')
        df.drop(columns=['current_time'], inplace=True)
        df = df.astype({col: "float64" for col in df.select_dtypes(include=["int"]).columns})
        data = df.drop(columns=['is_fraud'])

        print("making prediction...")
   

        # Predict on a Pandas DataFrame.
        prediction = loaded_model.predict(pd.DataFrame(data))

        print(f"Prediction for transaction: {prediction[0]}")

        # Add prediction to DataFrame
        df['prediction'] = prediction

        # Save transaction with prediction to database
        print("saving transaction to database...")

        # Écrire tout le DataFrame
        df.to_sql('transactions', engine, if_exists='append', index=False)
        wait_time = 10
        
    else :
        print(f"An error {r.status_code} occurred:", r.reason)
        wait_time = 60
    
    print(f"waiting for {wait_time} seconds before next transaction...\n")
    import time
    time.sleep(wait_time)

print("ending...")
# Out:
# =====================================
# --- Processing transaction 1 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 2 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 3 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 4 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 5 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 6 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 7 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 8 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 9 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 10 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 11 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 12 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 13 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 14 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 15 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 16 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 17 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 1.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 18 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 19 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 20 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 21 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 22 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 23 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 24 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 25 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 26 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 27 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 28 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 29 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 30 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 31 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 32 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 33 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 34 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 35 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 36 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 37 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 38 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 39 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 40 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 41 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 42 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 43 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 44 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 45 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 46 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 47 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 48 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 49 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 50 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 51 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 52 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 53 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 54 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 55 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 56 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 57 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 58 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 59 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 60 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 61 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 62 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 63 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 64 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 65 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 66 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 67 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 68 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 69 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 70 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 71 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 72 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 73 ---
# calling API to generate transaction...
# An error 500 occurred: Internal Server Error
# waiting for 60 seconds before next transaction...
#
# =====================================
# --- Processing transaction 74 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 75 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 76 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 77 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 78 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 79 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 80 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 81 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 82 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 83 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 84 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 85 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 86 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 87 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 88 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 89 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 90 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 91 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 92 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 93 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 94 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 95 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 96 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 97 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
#
# =====================================
# --- Processing transaction 98 ---
# calling API to generate transaction...
# making prediction...
# Prediction for transaction: 0.0
# saving transaction to database...
# waiting for 10 seconds before next transaction...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 71
#      69     print(f"waiting for {wait_time} seconds before next transaction...\n")
#      70     import time
# ---> 71     time.sleep(wait_time)
#      73 print("ending...")
#
# KeyboardInterrupt:

# %%
print(r)
# Out:
# <Response [200]>
